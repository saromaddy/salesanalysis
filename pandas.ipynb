# %%
import pandas as pd

# %%
features_df = pd.read_csv(r"/Users/saro/Desktop/salesanalysis/Features_data_set.csv")
features_df
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  05/02/2010        42.31       2.572        NaN        NaN
# 1         1  12/02/2010        38.51       2.548        NaN        NaN
# 2         1  19/02/2010        39.93       2.514        NaN        NaN
# 3         1  26/02/2010        46.63       2.561        NaN        NaN
# 4         1  05/03/2010        46.50       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8185     45  28/06/2013        76.05       3.639    4842.29     975.03
# 8186     45  05/07/2013        77.50       3.614    9090.48    2268.58
# 8187     45  12/07/2013        79.37       3.614    3789.94    1827.31
# 8188     45  19/07/2013        82.84       3.737    2961.49    1047.07
# 8189     45  26/07/2013        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# ...

# %%
sales_df = pd.read_csv(r"/Users/saro/Desktop/salesanalysis/sales_data_set.csv")
sales_df
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday
# 0           1     1  05/02/2010      24924.50      False
# 1           1     1  12/02/2010      46039.49       True
# 2           1     1  19/02/2010      41595.55      False
# 3           1     1  26/02/2010      19403.54      False
# 4           1     1  05/03/2010      21827.90      False
# ...       ...   ...         ...           ...        ...
# 421565     45    98  28/09/2012        508.37      False
# 421566     45    98  05/10/2012        628.10      False
# 421567     45    98  12/10/2012       1061.02      False
# 421568     45    98  19/10/2012        760.01      False
# 421569     45    98  26/10/2012       1076.80      False
#
# [421570 rows x 5 columns]

# %%
stores_df = pd.read_csv(r"/Users/saro/Desktop/salesanalysis/stores_data_set.csv")
stores_df
# Out:
#     Store Type    Size
# 0       1    A  151315
# 1       2    A  202307
# 2       3    B   37392
# 3       4    A  205863
# 4       5    B   34875
# 5       6    A  202505
# 6       7    B   70713
# 7       8    A  155078
# 8       9    B  125833
# 9      10    B  126512
# 10     11    A  207499
# 11     12    B  112238
# 12     13    A  219622
# 13     14    A  200898
# 14     15    B  123737
# 15     16    B   57197
# 16     17    B   93188
# 17     18    B  120653
# 18     19    A  203819
# 19     20    A  203742
# 20     21    B  140167
# 21     22    B  119557
# 22     23    B  114533
# 23     24    A  203819
# 24     25    B  128107
# 25     26    A  152513
# 26     27    A  204184
# 27     28    A  206302
# 28     29    B   93638
# 29     30    C   42988
# 30     31    A  203750
# 31     32    A  203007
# 32     33    A   39690
# 33     34    A  158114
# 34     35    B  103681
# 35     36    A   39910
# 36     37    C   39910
# 37     38    C   39690
# 38     39    A  184109
# ...

# %%
#Average customer visits in type B stores in April months (3 years)

#Allsalesprice on that particular date/CPI = total customer visits on all department in a particular store

# %%
#Exploratory Data Analysis

# %%
print(features_df.describe(include='all'))
print(sales_df.describe(include='all'))
print(stores_df.describe(include='all'))
# Out:
#               Store        Date  Temperature   Fuel_Price      MarkDown1  \
# count   8190.000000        8190  8190.000000  8190.000000    4032.000000
# unique          NaN         182          NaN          NaN            NaN
# top             NaN  05/02/2010          NaN          NaN            NaN
# freq            NaN          45          NaN          NaN            NaN
# mean      23.000000         NaN    59.356198     3.405992    7032.371786
# std       12.987966         NaN    18.678607     0.431337    9262.747448
# min        1.000000         NaN    -7.290000     2.472000   -2781.450000
# 25%       12.000000         NaN    45.902500     3.041000    1577.532500
# 50%       23.000000         NaN    60.710000     3.513000    4743.580000
# 75%       34.000000         NaN    73.880000     3.743000    8923.310000
# max       45.000000         NaN   101.950000     4.468000  103184.980000
#
#             MarkDown2      MarkDown3     MarkDown4      MarkDown5  \
# ...

# %%
print(features_df.isnull().sum())
print(sales_df.isnull().sum())
print(stores_df.isnull().sum())
# Out:
# Store              0
# Date               0
# Temperature        0
# Fuel_Price         0
# MarkDown1       4158
# MarkDown2       5269
# MarkDown3       4577
# MarkDown4       4726
# MarkDown5       4140
# CPI              585
# Unemployment     585
# IsHoliday          0
# dtype: int64
# Store           0
# Dept            0
# Date            0
# Weekly_Sales    0
# IsHoliday       0
# dtype: int64
# Store    0
# Type     0
# Size     0
# dtype: int64

# %%
merged_df = sales_df.merge(features_df, on=['Store', 'Date']).merge(stores_df, on='Store')

sns.scatterplot(data=merged_df, x='Temperature', y='Weekly_Sales')
plt.show()

sns.scatterplot(data=merged_df, x='Fuel_Price', y='Weekly_Sales')
plt.show()

# %%
type(merged_df['Date'][0])

# time_series = merged_df.groupby('Date')['Weekly_Sales'].sum()
# time_series.plot()
# plt.show()
# Out:
# str

# %%
pip install sweetviz
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 15.1 MB 16.0 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 24.1.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import sweetviz as sv

myreport = sv.analyze(stores_df)
myreport.show_html()
# Out:
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:00 -> (00:00 left)
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
